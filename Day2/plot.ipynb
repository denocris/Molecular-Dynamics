# %%
import numpy as np
from pylab import *

# %%
def readfile(filename):
    ret = open("%s" %(filename),"r")
    ret = [line for line in ret]
    ret = [float(line.strip()) for line in ret]
    return ret

time_task_A = readfile("data/time_A.dat") 
time_task_B = readfile("data/time_B.dat") 
time_linkedcell = readfile("data/time_linkedcells.dat") 

nprocs = [1,2,4,8,16,20]

plt.figure(figsize=(14,10))
plt.title("Scaling of the simplemd code")
plt.plot(nprocs,time_task_A, "--o", color = "red", label = "parallel compute force")
plt.plot(nprocs,time_task_B, "--o", color = "blue", label = "parallel compute force AND compute list")
plt.plot(nprocs,time_linkedcell, "--o", color = "green", label = "linked cells + Round Robin")
plt.legend(loc="upper right", fontsize=15)
plt.text(14, 235, r'./lattice $16$ , $natoms =16384$', fontsize=15)
plt.text(14, 200, r'$listcutoff =3.0$', fontsize=15)
plt.savefig('scaling.png')
plt.show()

# %%
def readfile(filename):
    ret = open("%s" %(filename),"r")
    ret = [line for line in ret]
    ret = [float(line.strip()) for line in ret]
    return ret

readfile("data/time_A.dat")
# Out:
# [257.26, 262.96, 251.67, 176.81, 47.24, 47.95]

# %%
print taskA
# Out:
# ['257.26\n', '262.96\n', '251.67\n', '176.81\n', '47.24\n', '47.95\n']

# %%
taskB = [line for line in taskB]



nprocs = np.array([1,2,4,8,16,20])

plt.title("Scaling of the simplemd code")
plt.plot(nprocs,taskA, "o", "r")
plt.plot(nprocs,taskB, "o", "b")
plt.show()
